# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelandika/Pemerograman-Dasar/blob/main/pertemuan%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jawaban latihan 1

tegangan_panel = (18)
arus_panel = (6)
jenis_sel = ('Monocrystalline')

print (tegangan_panel)
print (arus_panel)
print (jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
#jawaban latihan 2

nilai_resistor = (10)
nilai_kapasitor = (20.15)
fungsi_transistor = ('Penguat_arus')
berfungsi = True

print (type (nilai_resistor))
print (type (nilai_kapasitor))
print (type (fungsi_transistor))
print (type (berfungsi))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#jawaban latihan 3


nama_unit = ('plts_nunukan')
jumlah_panel = (240)
tegangan_keluaran = (48.5)
sedang_beroperasi = True

print (type (nama_unit))
print (type (jumlah_panel))
print (type (tegangan_keluaran))
print (type (sedang_beroperasi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#jawaban latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#a
print ('tegangan harian ke-1 :',tegangan_harian[0])
print ('tegangan harian ke-5 :',tegangan_harian[5])

#b
tegangan_harian.append(222.0)
print("Setelah ditambah:", tegangan_harian)

#c
print (len(tegangan_harian))
# Out:
# tegangan harian ke-1 : 217.5
# tegangan harian ke-5 : 216.9
# Setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# 7

# %%
#jawaban latihan 5

motor_listrik = {'nama': "hitachi", 'daya_kw': 64.5, 'tegangan_v': 220, 'rpm': 2500}
print (motor_listrik['nama'])
motor_listrik ['rpm'] = 3000
print (motor_listrik)
# Out:
# hitachi
# {'nama': 'hitachi', 'daya_kw': 64.5, 'tegangan_v': 220, 'rpm': 3000}

# %%
#jawaban latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print ('unit-2 :',pembangkit[1])

pembangkit[0]["status"] = "pemeliharaan"

pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 120, "status": "operasi"})

print("\nSeluruh data pembangkit:")
for unit in pembangkit:
    print(unit)
# Out:
# unit-2 : {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
#
# Seluruh data pembangkit:
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}
# {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}
