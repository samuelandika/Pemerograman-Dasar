# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelandika/Pemerograman-Dasar/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nama   : Samuel Andika Situmorang
# NIM    : 4232501019
# Tanggal: 25/09/2026
# Tujuan : Menghitung operasi aritmatika dari dua bilangan

bilangan1 = int(input("Masukkan bilangan pertama: "))
bilangan2 = int(input("Masukkan bilangan kedua: "))

print ("===OPERASI ARITMATIKA===")

bilangan1 = int(input("masukkan bilangan pertama:"))
bilangan2 = int(input("masukkan bilangan kedua:"))

print("/Hasil operasi:")
print(f"penjumlahan :{bilangan1 + bilangan2}")
print(f"pengurangan :{bilangan1 - bilangan2}")
print(f"perkalian :{bilangan1 * bilangan2}")
print(f"pembagian :{bilangan1 / bilangan2}")
print(f"pembagian bulat :{bilangan1 // bilangan2}")
print(f"modulus :{bilangan1 % bilangan2}")


# Nama   : Samuel Andika Situmorang
# NIM    : 4232501019
# Tanggal: 25/09/2026
# Tujuan : Mengecek apakah nilai ujian termasuk kategori lulus

nilai = int(input("Masukkan nilai ujian (0-100): "))
lulus = nilai >= 60
print(f"Apakah nilai ini termasuk kategori lulus (>= 60)? {lulus}")


# Nama   : Samuel Andika Situmorang
# NIM    : 4232501019
# Tanggal: 25/09/2026
# Tujuan : Menentukan apakah seseorang boleh mengemudi sendiri

print ("===OPERATOR LOGIKA===")

umur = int(input("masukkan umur:"))
sim = int(input("apakah memiliki SIM? (1 = Ya, 0 = Tidak):"))
punya_sim = sim == 1
boleh_mengemudi = (umur >=17) and punya_sim
print(f"Apakah boleh mengemudi sendiri?{boleh_mengemudi}")


# Nama   : Samuel Andika Situmorang
# NIM    : 4232501019
# Tanggal: 25/09/2026
# Tujuan : Menghitung efisiensi termal unit pembangki

print("===EFISIENSI TERMAL PEMBANGKIT===")

energi_input = float(input("Masukkan energi input(MJ):"))
energi_output = float(input("Masukkan energi output(MJ):"))
efisiensi = (energi_output / energi_input)*100
print(f"efisiensi termal pembangkit adalah{efisiensi:.2f}%")


# Nama   : Samuel Andika Situmorang
# NIM    : 4232501019
# Tanggal: 25/09/2026
# Tujuan : Menentukan apakah unit pembangkit perlu maintenance


print("===KONDISI MAINTENANCE PEMBANGKIT===")

suhu_boiler = float(input("Masukkan suhu boiler (Celsius):"))
beban_operasi = float(input("Masukkan beban operasi (%):"))
perlu_maintenance = (suhu_boiler > 550) or(beban_operasi > 95)
print(f"Apakah unit pembangkit perlu maintenance?{perlu_maintenance}")
# Out:
# Masukkan bilangan pertama: 15
# Masukkan bilangan kedua: 5
# ===OPERASI ARITMATIKA===
# masukkan bilangan pertama:16
# masukkan bilangan kedua:4
# /Hasil operasi:
# penjumlahan :20
# pengurangan :12
# perkalian :64
# pembagian :4.0
# pembagian bulat :4
# modulus :0
# Masukkan nilai ujian (0-100): 88
# Apakah nilai ini termasuk kategori lulus (>= 60)? True
# ===OPERATOR LOGIKA===
# masukkan umur:21
# apakah memiliki SIM? (1 = Ya, 0 = Tidak):1
# Apakah boleh mengemudi sendiri?True
# ===EFISIENSI TERMAL PEMBANGKIT===
# Masukkan energi input(MJ):1200
# Masukkan energi output(MJ):360
# efisiensi termal pembangkit adalah30.00%
# ===KONDISI MAINTENANCE PEMBANGKIT===
# Masukkan suhu boiler (Celsius):580
# Masukkan beban operasi (%):85
# Apakah unit pembangkit perlu maintenance?True
