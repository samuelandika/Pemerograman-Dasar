# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelandika/Pemerograman-Dasar/blob/main/BIODATASAYA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "samuel"
nim = "4232501019"
umur = 19
asalsekolah = "sman 5 batam"
jurusan = "elektro"
semester = 3
matakuliah = 'Pemerograman Dasar'
email = "situmorangsamuelandika@gmail.com"
kewarganegaraan = "indonesia"
status_lulus = False


print (nama)
print (nim)
print (umur)
print (asalsekolah)
print (jurusan)
print (semester)
print (matakuliah)
print (email)
print (kewarganegaraan)
print (status_lulus)
# Out:
# samuel
# 4232501019
# 19
# sman 5 batam
# elektro
# 3
# Pemerograman Dasar
# situmorangsamuelandika@gmail.com
# indonesia
# False
